# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y, color = "firebrick", marker = "^", linewidth= 0.1) #..label='xy')
plt.plot(x,z, color = "chartreuse", linestyle="dashed", linewidth=2)
# plt.legend()   this displays the box in top left corner, but to show anything we need to write a label parameter in at least on of the graph info
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig,(a1,a2) = plt.subplots(nrows=1, ncols=2)
a1.plot(x,y)
a2.plot(x,z,marker = "^")
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
f,(a1,a2) = plt.subplots(nrows=1, ncols=2, figsize =(20,10))
a1.plot(x,y)
a2.plot(x,z)
#plt.xlabel('x label') it's applicable to the plot that is written firs above it
plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here    
f,(a1,a2) = plt.subplots(nrows =1, ncols=2)
a1.set_yscale("log")
a1.set_xscale("log")
a1.plot(x,np.exp(x), label = "exp")
a1.plot(x, x**2, label = "square")
a1.title.set_text("log scale")
a1.legend()
a2.plot(x,np.exp(x))
a2.plot(x, x**2)
a2.title.set_text("normal scale")

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit2 = pd.read_csv("Fitbit2.csv")
fitbit2.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
f,(a1,a2) = plt.subplots(nrows=1, ncols=2, figsize =(12,4))
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
a1.scatter(fitbit2["Months_encoded"],fitbit2["Steps"])
a1.set_xlabel("Months")
a1.set_ylabel("Steps")
# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
a2.scatter(fitbit2["Work_or_Weekend"],fitbit2["Steps"])
plt.sca(a2)
plt.xticks([0,1], ["Weekend",'Work'])
plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
f,axes = plt.subplots(nrows=1, ncols=3, figsize =(12,4))
analysis=["Minutes Lightly Active","Minutes Very Active","Minutes Sedentary"]
[axes[ele].scatter(fitbit2["Steps"],fitbit2[analysis[ele]]) for ele in range(3)]
plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv("titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include = "number")
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include = "object")  #categoric
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
mpl.style.use('classic')    #sns.set_style(darkgrid or whitegrid or dark or white or ticks)
plt.figure(figsize=(12,6))  #only applies to the figures within this cell

# %%
#  mpl.style.use("default")   revert style to normal

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
titanic["Age"].plot(kind = 'hist',figsize=(12,6))
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
# teste: n, bins, patches = plt.hist(titanic["Age"], bins = [0,10,30,80])
ig, ax = plt.subplots(1,3, figsize = (12,6))
ages = titanic['Age']
ax[0].hist(ages, bins = 10)
ax[1].hist(ages, bins = 20)
ax[2].hist(ages, bins = 50)
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""It seems that the bigger the bins the higher the corresponding values in the y axis, as it encompases a wider variaty of in this case ages,  and so the scale will alter. ALso visually is not as beutiful :)"""
# Out:
# 'It seems that the bigger the bins the higher the corresponding values in the y axis, as it encompases a wider variaty of in this case ages,  and so the scale will alter. ALso visually is not as beutiful :)'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.distplot(titanic["Age"])

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
titanic["Gender"].value_counts().plot(kind = "bar")

# %%
# Method 2 - seaborn
# your code here
sns.countplot(x="Gender", data=titanic)

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.countplot(x="Pclass", data=titanic)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
plt.boxplot(titanic["Age"])
plt.figtext(0.6,0.5, titanic["Age"].describe().to_string())
plt.show()

# %%
"""I choose the boxplot because it provides information about the three quartile (25%,50%,75%), as well as gives us the extreme values (máx & min). Giving us an overvies of actual observations, including outliers"""
# Out:
# 'I choose the boxplot because it provides information about the three quartile (25%,50%,75%), as well as gives us the extreme values (máx & min). Giving us an overvies of actual observations, including outliers'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""The minimum age is close to zero, max close to 80 and mean aproximatly 30 years."""
# Out:
# 'The minimum age is close to zero, max close to 80 and mean aproximatly 30 years.'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.catplot(y = 'Age', data = titanic, kind = 'violin')

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""I chose the catplot with violin shape, because it gives us the information that the boxplot gives, with the addition of also showing the distribution of values"""
# Out:
# 'I chose the catplot with violin shape, because it gives us the information that the boxplot gives, with the addition of also showing the distribution of values'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.scatter(titanic["Age"], titanic["Fare"])

# %%
# Method 2 - seaborn
# your code here
sns.regplot(x="Age", y="Fare", data=titanic)

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
sns.heatmap(titanic.corr(),annot=True, xticklabels = titanic.corr().columns,yticklabels = titanic.corr().columns)

# %% [markdown]
# #### What are the most correlated features?

# %%
"""The highest correlated features (are each variable with itself and then) are SibSp and Parch"""
# Out:
# 'The highest correlated features (are each variable with itself and then) are SibSp and Parch'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
f = plt.figure(1, figsize=(9, 6))
box = titanic[['Pclass','Age']].boxplot(by = 'Pclass')
plt.show()
# Out:
# C:\Users\maria\Anaconda3\envs\Ironhack\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
f = sns.FacetGrid(titanic, col="Gender")
f.map(plt.hist, "Age")
